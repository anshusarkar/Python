# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(10000) # x contains an array of 10000 values 

plt.hist(x, 100)

plt.title(r'Normal distrubition with $\mu=0, \sigma=1$')
plt.savefig('matplotlib.png')
plt.show()
