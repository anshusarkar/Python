# %%
import tensorflow as tf 
from tensorflow import keras as k 
import numpy as np

# %% [markdown]
# # Defining the nural network from keras

# %%
model = k.Sequential([k.layers.Dense(units=1, input_shape=[1])]) # It's a neuron with one layer and one input value 

model.compile(optimizer = 'sgd', loss = 'mean_squared_error') # sgd i.e. stocastic gradient descent 

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype = float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype = float)

#link = https://www.coursera.org/learn/introduction-tensorflow/lecture/kr51q/the-hello-world-of-neural-networks

model.fit(xs, ys, epochs = 500) # an epoch is an unit that actualy counts the number of iterations of the a dataset as an input 

# Now the NN of keras would try to predict the relation between xs and ys

print(model.predict([1]))

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 224ms/step - loss: 15.4436
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 12.3929
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.9878
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0907
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 6.5933
# Epoch 6/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4106
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4755
# Epoch 8/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.7353
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.1486
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6827
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 2.3119
# Epoch 12/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0160
# ...
